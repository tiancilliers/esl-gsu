# %%
res = [1e3,10e3,4.7e3,100,100e3,22,20e3,5.1e3,47e3,10,2e3,1e6,2.2e3,510,330,22e3,33,470,3.3e3,15e3,49.9,1.5e3,220,51e3,200,200e3,12e3,33e3,120,510e3,1,300e3,120e3,47,150,6.8e3,150e3,680,7.5e3,75,1.2e3,220e3,300,49.9e3,8.2e3,18e3,470e3,51,56e3,39e3,5.6e3,75e3,330e3,68e3,3.9e3,24e3,2.4e3,27e3]

vnom = 5
limit = 50e3

val = [(1.2*(r1+r2+r3)/(r2+r3),1.2*(r1+r2+r3)/(r3),r1,r2,r3) for r1 in res for r2 in res for r3 in res if r1+r2+r3>limit]
sorted([v for v in val if v[0] < vnom and v[1] > vnom], key=lambda t: abs(t[0]-4.75)+abs(t[1]-5.25))[:20]
# Out:
# [(4.745454545454545, 5.22, 39000.0, 1200.0, 12000.0),
#  (4.729411764705882, 5.20235294117647, 220000.0, 6800.0, 68000.0),
#  (4.735714285714286, 5.304, 330000.0, 12000.0, 100000.0),
#  (4.8, 5.28, 330000.0, 10000.0, 100000.0),
#  (4.666666666666667, 5.25, 39000.0, 1500.0, 12000.0),
#  (4.696688741721855, 5.214705882352941, 220000.0, 7500.0, 68000.0),
#  (4.8, 5.2, 39000.0, 1000.0, 12000.0),
#  (4.78695652173913, 5.181176470588236, 220000.0, 5600.0, 68000.0),
#  (4.6645669291338585, 5.227058823529412, 220000.0, 8200.0, 68000.0),
#  (4.739823008849558, 5.356, 1000000.0, 39000.0, 300000.0),
#  (4.859889094269871, 5.2584, 330000.0, 8200.0, 100000.0),
#  (4.722352941176471, 5.352, 49900.0, 2000.0, 15000.0),
#  (4.883720930232558, 5.25, 330000.0, 7500.0, 100000.0),
#  (4.736345776031434, 5.129361702127659, 150000.0, 3900.0, 47000.0),
#  (4.803603603603603, 5.332, 1000000.0, 33000.0, 300000.0),
#  (4.811491108071135, 5.17235294117647, 220000.0, 5100.0, 68000.0),
# ...

# %%
r1 = 470e3
r2 = 15e3
r3 = 150e3
(1.2*(r1+r2+r3)/(r2+r3),1.2*(r1+r2+r3)/(r3),r1,r2,r3)
# Out:
# (4.618181818181818, 5.08, 470000.0, 15000.0, 150000.0)

# %%
res = [1e3,10e3,4.7e3,100,100e3,22,20e3,5.1e3,47e3,10,2e3,1e6,2.2e3,510,330,22e3,33,470,3.3e3,15e3,49.9,1.5e3,220,51e3,200,200e3,12e3,33e3,120,510e3,1,300e3,120e3,47,150,6.8e3,150e3,680,7.5e3,75,1.2e3,220e3,300,49.9e3,8.2e3,18e3,470e3,51,56e3,39e3,5.6e3,75e3,330e3,68e3,3.9e3,24e3,2.4e3,27e3]

vnom = 8.25

val = [(1*(r1+r2+r3)/(r3),r1,r2,r3) for r1 in res for r2 in res for r3 in res if r1+r2>=100e3 and r1+r2<=440e3]
sorted(val, key=lambda t: abs(t[0]-vnom))[:5]
# Out:
# [(8.25, 150000.0, 24000.0, 24000.0),
#  (8.25, 24000.0, 150000.0, 24000.0),
#  (8.254901960784315, 150000.0, 220000.0, 51000.0),
#  (8.254901960784315, 220000.0, 150000.0, 51000.0),
#  (8.242424242424242, 200000.0, 39000.0, 33000.0)]

# %%
res = [1e3,10e3,4.7e3,100,100e3,22,20e3,5.1e3,47e3,10,2e3,1e6,2.2e3,510,330,22e3,33,470,3.3e3,15e3,49.9,1.5e3,220,51e3,200,200e3,12e3,33e3,120,510e3,1,300e3,120e3,47,150,6.8e3,150e3,680,7.5e3,75,1.2e3,220e3,300,49.9e3,8.2e3,18e3,470e3,51,56e3,39e3,5.6e3,75e3,330e3,68e3,3.9e3,24e3,2.4e3,27e3]
sorted(res, key=lambda t: abs(310-t))[:5]
# Out:
# [300, 330, 220, 200, 470]

# %%
res = [1e3,10e3,4.7e3,100,100e3,22,20e3,5.1e3,47e3,10,2e3,1e6,2.2e3,510,330,22e3,33,470,3.3e3,15e3,49.9,1.5e3,220,51e3,200,200e3,12e3,33e3,120,510e3,1,300e3,120e3,47,150,6.8e3,150e3,680,7.5e3,75,1.2e3,220e3,300,49.9e3,8.2e3,18e3,470e3,51,56e3,39e3,5.6e3,75e3,330e3,68e3,3.9e3,24e3,2.4e3,27e3]
sorted([(r1+r2,r1,r2) for r1 in res for r2 in res], key=lambda t: abs(700e3-t[0]))[:5]
# Out:
# [(710000.0, 200000.0, 510000.0),
#  (710000.0, 510000.0, 200000.0),
#  (690000.0, 220000.0, 470000.0),
#  (690000.0, 470000.0, 220000.0),
#  (670000.0, 200000.0, 470000.0)]

# %%
res = [1e3,10e3,4.7e3,100,100e3,22,20e3,5.1e3,47e3,10,2e3,1e6,2.2e3,510,330,22e3,33,470,3.3e3,15e3,49.9,1.5e3,220,51e3,200,200e3,12e3,33e3,120,510e3,1,300e3,120e3,47,150,6.8e3,150e3,680,7.5e3,75,1.2e3,220e3,300,49.9e3,8.2e3,18e3,470e3,51,56e3,39e3,5.6e3,75e3,330e3,68e3,3.9e3,24e3,2.4e3,27e3]
sorted([(r2/(r1+r2),r1,r2) for r1 in res for r2 in res if r1+r2 > 40e3 and r1+r2 < 100e3], key=lambda t: abs(0.5-t[0]))[:5]
# Out:
# [(0.5, 47000.0, 47000.0),
#  (0.5, 22000.0, 22000.0),
#  (0.5, 33000.0, 33000.0),
#  (0.5, 49900.0, 49900.0),
#  (0.5, 39000.0, 39000.0)]

# %%
3334/3
# Out:
# 1111.3333333333333

# %%
res = [1e3,10e3,4.7e3,100,100e3,22,20e3,5.1e3,47e3,10,2e3,1e6,2.2e3,510,330,22e3,33,470,3.3e3,15e3,49.9,1.5e3,220,51e3,200,200e3,12e3,33e3,120,510e3,1,300e3,120e3,47,150,6.8e3,150e3,680,7.5e3,75,1.2e3,220e3,300,49.9e3,8.2e3,18e3,470e3,51,56e3,39e3,5.6e3,75e3,330e3,68e3,3.9e3,24e3,2.4e3,27e3]

vnom = 5
limit = 15e3

val = [(1.2*(r1+r2+r3)/(r2+r3),1.2*(r1+r2+r3)/(r3),20*(r2+r3)/(r1+r2+r3),r1,r2,r3) for r1 in res for r2 in res for r3 in res if r1+r2+r3>limit]
sorted([v for v in val], key=lambda t: abs(t[0]-7)+abs(t[1]-20))[:10]
# Out:
# [(6.777464788732394, 20.05, 3.541147132169576, 33000.0, 4700.0, 2400.0),
#  (6.777464788732394, 20.05, 3.541147132169576, 330000.0, 47000.0, 24000.0),
#  (7.101639344262295,
#   19.69090909090909,
#   3.3795013850415514,
#   300000.0,
#   39000.0,
#   22000.0),
#  (6.691525423728813, 19.74, 3.5866261398176293, 27000.0, 3900.0, 2000.0),
#  (6.969230769230769,
#   19.414285714285715,
#   3.443708609271523,
#   75000.0,
#   10000.0,
#   5600.0),
#  (6.558592692828146, 20.195, 3.6593216142609557, 330000.0, 49900.0, 24000.0),
#  (6.417391304347826,
#   20.12727272727273,
#   3.7398373983739837,
#   300000.0,
#   47000.0,
#   22000.0),
#  (6.914285714285715, 19.36, 3.4710743801652892, 200000.0, 27000.0, 15000.0),
#  (6.48, 20.25, 3.7037037037037037, 33000.0, 5100.0, 2400.0),
#  (6.48, 20.25, 3.7037037037037037, 330000.0, 51000.0, 24000.0)]

# %%
res = [1e3,10e3,4.7e3,100,100e3,22,20e3,5.1e3,47e3,10,2e3,1e6,2.2e3,510,330,22e3,33,470,3.3e3,15e3,49.9,1.5e3,220,51e3,200,200e3,12e3,33e3,120,510e3,1,300e3,120e3,47,150,6.8e3,150e3,680,7.5e3,75,1.2e3,220e3,300,49.9e3,8.2e3,18e3,470e3,51,56e3,39e3,5.6e3,75e3,330e3,68e3,3.9e3,24e3,2.4e3,27e3]

vnom = 5
limit = 15e3

val = [(1.2*(r1+r2+r3+r4)/(r2+r3+r4),1.2*(r1+r2+r3+r4)/(r4),20*(r3+r4)/(r1+r2+r3+r4),r1,r2,r3,r4) for r1 in res for r2 in res for r3 in res for r4 in res if r1+r2+r3+r4>limit]
sorted([v for v in val], key=lambda t: abs(t[0]-6)+abs(t[1]-20)+abs(t[2]-3.3))[:10]
# Out:
# [(5.980876494023905,
#   20.016,
#   3.357314148681055,
#   200000.0,
#   8200.0,
#   27000.0,
#   15000.0),
#  (6.048484848484849,
#   19.96,
#   3.3667334669338675,
#   200000.0,
#   7500.0,
#   27000.0,
#   15000.0),
#  (5.961904761904762,
#   20.12142857142857,
#   3.3226837060702876,
#   75000.0,
#   3300.0,
#   10000.0,
#   5600.0),
#  (5.980876494023905,
#   20.016,
#   3.117505995203837,
#   100000.0,
#   5600.0,
#   12000.0,
#   7500.0),
#  (5.980876494023905,
#   20.016,
#   3.117505995203837,
#   1000000.0,
#   56000.0,
#   120000.0,
#   75000.0),
#  (5.944186046511628,
#   20.04705882352941,
#   3.1220657276995305,
#   68000.0,
#   3900.0,
#   8200.0,
#   5100.0),
#  (6.118032786885246,
#   19.904,
#   3.3762057877813505,
#   200000.0,
#   6800.0,
#   27000.0,
#   15000.0),
#  (5.971929824561403,
#   20.023529411764706,
#   3.5487661574618095,
#   68000.0,
#   2000.0,
#   10000.0,
#   5100.0),
#  (6.078048780487805,
#   19.936,
#   3.130016051364366,
#   100000.0,
# ...
